# %% [markdown]
# # Estatística Aplicada a Ciência de Dados: Lista de Exercícios - 02

# %% [markdown]
# 01. Numa tabela, cada linha representa:
#
# > (a) um indivíduo.
# >
# > (b) um atributo ou variável.

# %%
# @title  { run: "auto", vertical-output: true }

q1 = '(a)' #@param[' ', '(a)', '(b)']

answer = '(a)'

if q1 == answer:
  print('Resposta correta.')

else:
  print('Reveja a sua resposta.')
# Out:
# Resposta correta.

# %% [markdown]
# 02. Numa tabela, cada coluna representa:
#
# > (a) um indivíduo.
# >
# > (b) um atributo ou variável.

# %%
# @title  { run: "auto", vertical-output: true }

q2 = '(b)' #@param[' ', '(a)', '(b)']

answer = '(b)'

if q2 == answer:
  print('Resposta correta.')

else:
  print('Reveja a sua resposta.')
# Out:
# Resposta correta.

# %% [markdown]
# 03. Na tabela abaixo
#
# |     |Dia|Hora   |Local    |
# |:---:|:-:|:-----:|:-------:|
# |**0**|  3|15 h 20|Curitiba |
# |**1**|  5|11 h 13|São Paulo|
# |**2**| 11|08 h 11|Campinas |

# %% [markdown]
# Os números em negrito da primeira coluna (0, 1 e 2) representam:
#
# > (a) o índice dos atributos.
# >
# > (b) o tempo em milisegundos para a inserção dos valores naquela linha.
# >
# > (c) são valores aleatórios que o *pandas* insere para o seu autocontrole de execução.
# >
# > (d) o índice do indivíduo.
# >
# > (e) o índice das variáveis.

# %%
# @title  { run: "auto", vertical-output: true }

q3 = '(d)' #@param[' ', '(a)', '(b)', '(c)', '(d)', '(e)']

answer = '(d)'

if q3 == answer:
  print('Resposta correta.')

else:
  print('Reveja a sua resposta.')
# Out:
# Resposta correta.

# %% [markdown]
# 04. Usando a tabela presente no *link* a seguir, faça o que se pede:
#
# > [https://raw.githubusercontent.com/nightlySnoopy/database/main/titanic.csv](https://raw.githubusercontent.com/nightlySnoopy/database/main/titanic.csv)

# %% [markdown]
# (a) Chame a biblioteca *pandas* e utilize como *alias pd*.

# %%
import pandas as pd

# %% [markdown]
# (b) Atribua a tabela do link acima ao nome df4.

# %%
df4 = pd.read_csv("https://raw.githubusercontent.com/nightlySnoopy/database/main/titanic.csv")

# %% [markdown]
# (c) Visualize as 8 primeiras linhas dessa tabela usando o método *.head()*.

# %%
df4.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
#
#          Fare     Embarked
# ...

# %% [markdown]
# (d) Visualize as 5 últimas linhas dessa tabela usando o método *.tail()*.

# %%
df4.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age   Fare     Embarked
# 886    male  27.0  13.00  Southampton
# 887  female  19.0  30.00  Southampton
# 888  female   NaN  23.45  Southampton
# 889    male  26.0  30.00    Cherbourg
# 890    male  32.0   7.75   Queenstown

# %% [markdown]
# (e) Usando o método *.shape*, verifique quantas linhas e quantas colunas essa tabela apresenta.

# %%
df4.shape
# Out:
# (891, 8)

# %% [markdown]
# (f) Usando o método *.columns*, verifique o nome das colunas dessa tabela.

# %%
df4.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# (g) Usando o método *.info( )*, verifique a classificação dos valores presentes em cada uma das colunas da tabela *df4*.

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   Fare         891 non-null    float64
#  7   Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 55.8+ KB

# %% [markdown]
# 05. A tabela a seguir foi construída com dados de um conjunto de gestantes de um hospital norte americano na tentativa de verificar a influência do cigarro na massa do recém nascido. De forma geral, quanto menor a massa de um recém nascido, maiores são as chances dele ter alguma problema de saúde após seu nascimento.
#
# > [https://raw.githubusercontent.com/nightlySnoopy/database/main/birth.csv](https://raw.githubusercontent.com/nightlySnoopy/database/main/birth.csv)
#
# As colunas presentes nessa tabela são:
#
# * *Birth Weight*: massa em onça do bebê recém-nascido (1 onça $\equiv$ 	28.35 gramas);
#
# * *Gestational Days*: número de dias gestacionais;
#
# * *Maternal Age*: a idade da mãe completa em anos;
#
# * *Maternal Height*: a altura da mãe em em polegadas (1 polegada $\equiv$ 2.54 centímetros);
#
# * *Maternal Pregnancy Weight*: a massa da gestante em libras (1 libra $\equiv$ 0.4536 quilograma);
#
# * *Maternal Smoker*: se a mãe fumou ou não durante a gestação.

# %% [markdown]
# (a) Atribua a tabela do link acima ao nome df5.

# %%
df5 = pd.read_csv("https://raw.githubusercontent.com/nightlySnoopy/database/main/birth.csv")

# %% [markdown]
# (b) Visualize as 5 primeiras linhas dessa tabela:

# %%
df5.head(5)
# Out:
#    Birth Weight  Gestational Days  Maternal Age  Maternal Height  \
# 0           120               284            27               62
# 1           113               282            33               64
# 2           128               279            28               64
# 3           108               282            23               67
# 4           136               286            25               62
#
#    Maternal Pregnancy Weight  Maternal Smoker
# 0                        100            False
# 1                        135            False
# 2                        115             True
# 3                        125             True
# 4                         93            False

# %% [markdown]
# (c) Visualize apenas a coluna *Gestational Days*.

# %%
df5[['Gestational Days']]
# Out:
#       Gestational Days
# 0                  284
# 1                  282
# 2                  279
# 3                  282
# 4                  286
# ...                ...
# 1169               275
# 1170               265
# 1171               291
# 1172               281
# 1173               297
#
# [1174 rows x 1 columns]

# %% [markdown]
# (d) Visualize apenas a coluna *Gestational Days* e *Maternal Smoker*.

# %%
df5[['Gestational Days', 'Maternal Smoker']]
# Out:
#       Gestational Days  Maternal Smoker
# 0                  284            False
# 1                  282            False
# 2                  279             True
# 3                  282             True
# 4                  286            False
# ...                ...              ...
# 1169               275            False
# 1170               265            False
# 1171               291             True
# 1172               281            False
# 1173               297            False
#
# [1174 rows x 2 columns]

# %% [markdown]
# (e) Quantas amostras estão presentes nessa tabela? Utilize o método *.shape* e a função *len( )*.

# %%
# Usando o método shape (Substitua os ### abaixo pelas declarações adeaquadas):
print(df5.shape)

# Usando a função len (Substitua os ### abaixo pelas declarações adeaquadas):
print(len(df5))
# Out:
# (1174, 6)
# 1174

# %% [markdown]
# 6. Em Python, o valor booleano *True* tem valor matemático igual a 1, enquanto o valor *False* tem valor matemático igual a zero. Com base nisso:

# %% [markdown]
# (a) Calcule *True* + 5

# %%
True + 5
# Out:
# 6

# %% [markdown]
# (b) Calcule *False* - 8

# %%
False - 8
# Out:
# -8

# %% [markdown]
# (c) Calcule *False* $\times$ 2

# %%
False * 2
# Out:
# 0

# %% [markdown]
# (d) Calcule 10 $\div$ *True*

# %%
10 / True
# Out:
# 10.0

# %% [markdown]
# 7. Na próxima questão usaremos os dados das projeções desenvolvidas pelo IBGE. Os dados estão presentes no seguinte *link*:
#
# > [https://raw.githubusercontent.com/nightlySnoopy/database/main/projections.csv](https://raw.githubusercontent.com/nightlySnoopy/database/main/projections.csv)

# %% [markdown]
# (a) Atribua esses dados ao nome *df7*.

# %%
df7 = pd.read_csv("https://raw.githubusercontent.com/nightlySnoopy/database/main/projections.csv")

# %% [markdown]
# (b) Visualize as 4 últimas linhas dessa tabela.

# %%
df7.tail(4)
# Out:
#    G.Etário     2010     2011     2012     2013     2014     2015     2016  \
# 15    75-79  2597990  2688798  2797237  2913384  3023576  3121818  3211601
# 16    80-84  1689444  1727063  1764898  1807817  1861166  1926871  2004365
# 17    85-89   830529   901360   954570   996763  1032554  1065148  1097017
# 18      90+   455191   459166   484603   521252   562349   603580   645377
#
#        2017     2018  ...     2051     2052      2053      2054      2055  \
# 15  3292375  3376250  ...  9496727  9752138  10030863  10307408  10564467
# 16  2095235  2191860  ...  7075422  7159683   7246694   7358416   7506972
# 17  1129489  1165517  ...  4659375  4764254   4861528   4950167   5030651
# 18   688657   731945  ...  3794831  3953061   4110366   4263976   4412193
#
#         2056      2057      2058      2059      2060
# 15  10804204  11027068  11224976  11388373  11511971
# 16   7687508   7899218   8128899   8356311   8567809
# 17   5103867   5168499   5235780   5321722   5434778
# ...

# %% [markdown]
# (c) Quantas linhas e quantas colunas tem essa tabela?

# %%
df7.shape
# Out:
# (19, 52)

# %% [markdown]
# (d) Elimine a coluna **2010** de *df7*. Atribua essa nova tabela ao nome *df7d* e visualize o resultado.

# %%
df7d = df7.drop(columns=["2010"])
df7d
# Out:
#    G.Etário      2011      2012      2013      2014      2015      2016  \
# 0       0-4  14697433  14624301  14567170  14570070  14677159  14715112
# 1       5-9  15600504  15387507  15203145  15029641  14824271  14664918
# 2     10-14  17216843  16880174  16495325  16131984  15840860  15577214
# 3     15-19  17238401  17315601  17402809  17424089  17334096  17155615
# 4     20-24  17396868  17296030  17195219  17124785  17100769  17122881
# 5     25-29  17423848  17454135  17436877  17391346  17331851  17256322
# 6     30-34  16275019  16567575  16822855  17028854  17178656  17271648
# 7     35-39  14350827  14689558  15066579  15441748  15787821  16107943
# 8     40-44  13311309  13414041  13519509  13668343  13884283  14161178
# 9     45-49  12218181  12426314  12615601  12784211  12933598  13064058
# 10    50-54  10574366  10868062  11152415  11419933  11666086  11892707
# 11    55-59   8679820   8977656   9278724   9579705   9877881  10172542
# ...

# %% [markdown]
# (e) Elimine as colunas 2011 a 2013 e 2015 da tabela **df7d** atribuindo essa nova tabela ao nome **df7e**. Visualize o resultado.

# %%
df7e = df7d.drop(columns=["2011","2013","2015"])
df7e
# Out:
#    G.Etário      2012      2014      2016      2017      2018      2019  \
# 0       0-4  14624301  14570070  14715112  14720776  14787557  14798332
# 1       5-9  15387507  15029641  14664918  14593299  14537829  14542132
# 2     10-14  16880174  16131984  15577214  15365237  15182024  15009676
# 3     15-19  17315601  17424089  17155615  16821630  16439846  16079464
# 4     20-24  17296030  17124785  17122881  17203520  17294780  17319853
# 5     25-29  17454135  17391346  17256322  17161679  17068593  17004904
# 6     30-34  16567575  17028854  17271648  17306947  17296659  17258318
# 7     35-39  14689558  15441748  16107943  16402815  16661965  16872342
# 8     40-44  13414041  13668343  14161178  14500831  14879035  15255513
# 9     45-49  12426314  12784211  13064058  13171048  13281287  13434076
# 10    50-54  10868062  11419933  11892707  12102371  12293932  12465329
# 11    55-59   8977656   9579705  10172542  10463716  10746091  11012111
# ...

# %% [markdown]
# (f) Verifique os rótulos (nomes) das colunas da tabela **df7**.

# %%
df7.columns
# Out:
# Index(['G.Etário', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025',
#        '2026', '2027', '2028', '2029', '2030', '2031', '2032', '2033', '2034',
#        '2035', '2036', '2037', '2038', '2039', '2040', '2041', '2042', '2043',
#        '2044', '2045', '2046', '2047', '2048', '2049', '2050', '2051', '2052',
#        '2053', '2054', '2055', '2056', '2057', '2058', '2059', '2060'],
#       dtype='object')

# %% [markdown]
# (g) Crie uma **lista** de nome **deletar** cujos elementos são os *strings* dos valores de 2025 até 2060. Dica: Aproveite o <ins>resultado do item anterior</ins>.

# %%
deletar=['2025',
       '2026', '2027', '2028', '2029', '2030', '2031', '2032', '2033', '2034',
       '2035', '2036', '2037', '2038', '2039', '2040', '2041', '2042', '2043',
       '2044', '2045', '2046', '2047', '2048', '2049', '2050', '2051', '2052',
       '2053', '2054', '2055', '2056', '2057', '2058', '2059', '2060']

# %% [markdown]
# (h) Elimine as colunas de 2025 a 2060 da tabela **df7** atribuindo essa nova tabela ao próprio **df7**. Visualize o resultado. Dica: utilize o resultado do item anterior.

# %%
df7 = df7.drop(columns=deletar)
df7
# Out:
#    G.Etário      2010      2011      2012      2013      2014      2015  \
# 0       0-4  14858280  14697433  14624301  14567170  14570070  14677159
# 1       5-9  15865195  15600504  15387507  15203145  15029641  14824271
# 2     10-14  17397304  17216843  16880174  16495325  16131984  15840860
# 3     15-19  17219086  17238401  17315601  17402809  17424089  17334096
# 4     20-24  17476779  17396868  17296030  17195219  17124785  17100769
# 5     25-29  17334110  17423848  17454135  17436877  17391346  17331851
# 6     30-34  15955949  16275019  16567575  16822855  17028854  17178656
# 7     35-39  14075108  14350827  14689558  15066579  15441748  15787821
# 8     40-44  13184170  13311309  13414041  13519509  13668343  13884283
# 9     45-49  11992439  12218181  12426314  12615601  12784211  12933598
# 10    50-54  10276773  10574366  10868062  11152415  11419933  11666086
# 11    55-59   8387564   8679820   8977656   9278724   9579705   9877881
# ...

# %% [markdown]
# (i) A coluna *G.Etário* tem valores classificados como inteiros? E as outras colunas? Todas as linhas de todas as colunas estão preenchidas? Verifique usando o método adequado.

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   G.Etário  19 non-null     object
#  1   2010      19 non-null     int64
#  2   2011      19 non-null     int64
#  3   2012      19 non-null     int64
#  4   2013      19 non-null     int64
#  5   2014      19 non-null     int64
#  6   2015      19 non-null     int64
#  7   2016      19 non-null     int64
#  8   2017      19 non-null     int64
#  9   2018      19 non-null     int64
#  10  2019      19 non-null     int64
#  11  2020      19 non-null     int64
#  12  2021      19 non-null     int64
#  13  2022      19 non-null     int64
#  14  2023      19 non-null     int64
#  15  2024      19 non-null     int64
# dtypes: int64(15), object(1)
# memory usage: 2.5+ KB

# %% [markdown]
# 8. A tabela que será utilizada neste exercício são informações de laptops presentes no site espanhol [www.pccomponentes.com](www.pccomponentes.com). Nela se encontram todos os laptops presentes no mercado no dia 25 de junho de 2023.

# %% [markdown]
# (a) Atribua a tabela
#
# > [https://raw.githubusercontent.com/nightlySnoopy/database/main/laptops.csv](https://raw.githubusercontent.com/nightlySnoopy/database/main/laptops.csv)
#
# ao nome *df8*. Visualize as 5 primeiras linhas dela.

# %%
tab= ("https://raw.githubusercontent.com/nightlySnoopy/database/main/laptops.csv")
df8 = pd.read_csv(tab)
df8.head(5)
# Out:
#                                               Laptop Status   Brand  \
# 0  ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1  Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2  ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3  MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4  HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
#
#         Model            CPU  RAM  Storage Storage type       GPU  Screen  \
# 0  ExpertBook  Intel Core i5    8      512          SSD       NaN    15.6
# 1          Go  Intel Celeron    8      256          SSD       NaN    15.6
# 2  ExpertBook  Intel Core i3    8      256          SSD       NaN    15.6
# 3      Katana  Intel Core i7   16     1000          SSD  RTX 3050    15.6
# 4         15S  Intel Core i5   16      512          SSD       NaN    15.6
#
#   Touch  Final Price
# 0    No      1009.00
# 1    No       299.00
# 2    No       789.00
# ...

# %% [markdown]
# (b) Verifique as classificações dos valores e se todas as linhas estão preenchidas nessa tabela.

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laptop        2160 non-null   object
#  1   Status        2160 non-null   object
#  2   Brand         2160 non-null   object
#  3   Model         2160 non-null   object
#  4   CPU           2160 non-null   object
#  5   RAM           2160 non-null   int64
#  6   Storage       2160 non-null   int64
#  7   Storage type  2118 non-null   object
#  8   GPU           789 non-null    object
#  9   Screen        2156 non-null   float64
#  10  Touch         2160 non-null   object
#  11  Final Price   2160 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 202.6+ KB

# %% [markdown]
# (c) No total, quantas linhas estão presentes nessa tabela?

# %%
# @title  { run: "auto", vertical-output: true }
q8c = # @param {type:"integer"}

answer = 2160

if q8c == answer:
  print('Resposta correta.')

else:
  print('Reveja a sua resposta.')
# Out:
#   File "<ipython-input-1-a72afff8bcdd>", line 2
#     q8c = # @param {type:"integer"}
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# (d) Sabendo que a coluna *Screen* tem a medida da tela em polegadas, quantos laptops apresentam informações sobre essa característica?

# %%
# @title  { run: "auto", vertical-output: true }
q8d = # @param {type:"integer"}

answer = 2156

if q8d == answer:
  print('Resposta correta.')

else:
  print('Reveja a sua resposta.')

# %% [markdown]
# (e) Em quantos computadores estão faltando a informação do GPU?

# %%
# @title  { run: "auto", vertical-output: true }
q8e = # @param {type:"integer"}

answer = 1371

if q8e == answer:
  print('Resposta correta.')

else:
  print('Reveja a sua resposta.')
