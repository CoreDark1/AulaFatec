# %% [markdown]
# Nome: André Luiz Martendal da Silva, 9P, eng da comput, noite

# %% [markdown]
# 1) Crie um vetor com 5 elementos do tipo float.

# %%
vetor=[]
for i in range(5):

  vetor.append(float(input('digite um numero: ')))

print(vetor)
# Out:
# digite um numero: 2
# digite um numero: 3.6
# digite um numero: 4
# digite um numero: 5
# digite um numero: 7.9
# [2.0, 3.6, 4.0, 5.0, 7.9]

# %% [markdown]
# 2) Encontre o menor elemento no vetor.

# %%
print(min(vetor))
# Out:
# 2.0

# %% [markdown]
# 3) Substitua todos os números ímpares por -1.

# %%
for c, i in enumerate(vetor):
  if i % 2.0 != 0:
    vetor[c] = -1
print(vetor)
# Out:
# [2.0, -1, 4.0, -1, -1]

# %% [markdown]
# 4) Imprima o tamanho do vetor

# %%
print(len(vetor))
# Out:
# 5

# %% [markdown]
# 5) Acrescente um número na posição 4

# %%
vetor.insert(4, float(input('Digite outro numero: ')))
print(vetor)
# Out:
# Digite outro numero: 7.9
# [2.0, -1, 4.0, -1, 7.9, -1]

# %% [markdown]
# 6) Escreva uma função que receba uma lista de números e retorne o menor valor.

# %%
def menorValor(lista):
  valorMenor = min(lista)
  return valorMenor

result = menorValor(vetor)
print(f'O menor valor da lista é: {result}' )
# Out:
# O menor valor da lista é: -1

# %% [markdown]
# 7) Escreva uma função que receba uma lista de números e retorne o que a soma dos números pares.

# %%
def somaValor(lista):
  soma=0
  for i in lista:
        if i % 2.0 == 0:
               soma = soma + i

  return soma

result = somaValor(vetor)
print(f'O menor valor da lista é: {result}' )
# Out:
# O menor valor da lista é: 6.0

# %% [markdown]
# 8) Crie uma função que receba um número e informe o perímetro do quadrado.

# %%
def perimetro(numero):
  return 4 * numero

valor=(float(input('Digite um numero: ')))

result = perimetro(valor)

print(f'O perimetro do quadrado é: {result}')
# Out:
# Digite um numero: 5
# O perimetro do quadrado é: 20.0

# %% [markdown]
# 9) Crie uma função que receba o tempo em minutos e informe quantos segundos tem nele.

# %%
def tempo(segundo):
  return segundo * 60

minuto = (int(input('Digite o tempo em minutos: ')))
result = tempo(minuto)

print(f'{minuto} min, o que vale à {result} em segundos ')
# Out:
# Digite o tempo em minutos: 30
# 30 min, o que vale à 1800 em segundos

# %% [markdown]
# 10) Crie uma função que receba um número e retorne seu quadrado.

# %%
def quadrado(num):
  return num * num

valor=(float(input('Digite um numero: ')))

result = quadrado(valor)

print(f'O valor ao quadrado é: {result}')
# Out:
# Digite um numero: 20
# O valor ao quadrado é: 400.0
